# %% [markdown]
# # Scrapping Data Review Wisata Indonesia dengan SerpAPI
#
# ---

# %% [markdown]
# *   **Install Modul Python Google Search Results**

# %%
pip install google-search-results
# Out:
# Collecting google-search-results
#   Downloading google_search_results-2.4.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from google-search-results) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->google-search-results) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->google-search-results) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->google-search-results) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->google-search-results) (2024.2.2)
# Building wheels for collected packages: google-search-results
#   Building wheel for google-search-results (setup.py) ... done
#   Created wheel for google-search-results: filename=google_search_results-2.4.2-py3-none-any.whl size=32003 sha256=4f14c29013655c0066e9eb7cb86da227b24dabc7cd58d658f1b42f3139f78e0a
#   Stored in directory: /root/.cache/pip/wheels/d3/b2/c3/03302d12bb44a2cdff3c9371f31b72c0c4e84b8d2285eeac53
# Successfully built google-search-results
# Installing collected packages: google-search-results
# Successfully installed google-search-results-2.4.2

# %% [markdown]
# *   **Import Library Google**

# %%
from serpapi import GoogleSearch
from urllib.parse import *

# %% [markdown]
# *   **Scrapping Hasil Data**
#
#    mengambil 15 objek wisata yang memiliki ≥ 1000 views

# %%
params = {
    "engine": "google_maps",
    "q": "wisata indonesia",
    "ll": "@-7.4548074,110.1102104,10z",
    "type": "search",
    "api_key": "1e15cb862401aac1d0ceb77f9bc8a132174b60004dacfe264e7524db24e39878",
    "hl": "id",
    "gl": "id"
}

search = GoogleSearch(params)

idx = 0
last = 15
local_results = []

while idx <= last:

  results = search.get_dict()

  for Result in results['local_results']:
    idx += 1

    if idx <= last:

      if Result["reviews"] < 1000:
        idx += 1
        continue

      local_results.append({'Nama': Result["title"],
                            'data_id': Result["data_id"],
                            'total_reviews': Result["reviews"]});

  if "next" in results.get("serpapi_pagination", {}):
    search.params_dict.update(dict(parse_qsl(urlsplit(results.get("serpapi_pagination").get("next")).query)))
  else:
    break

# %%
for lr in local_results:
  print(lr)
# Out:
# {'Nama': 'Candi Borobudur', 'data_id': '0x2e7a8cf009a7d697:0xdd34334744dc3cb', 'total_reviews': 94376}
# {'Nama': 'Kampung Wisata Taman Sari', 'data_id': '0x2e7a5793d0c2cf2b:0x276a21f8a01cbe13', 'total_reviews': 39999}
# {'Nama': 'Candi Prambanan', 'data_id': '0x2e7a5ae3dbd859d1:0x19e7a03b25955a2d', 'total_reviews': 91340}
# {'Nama': 'Goa Jomblang', 'data_id': '0x2e7bb41fce34d717:0xf9ffcb6f9fbd5cce', 'total_reviews': 1205}
# {'Nama': 'Ketep Pass', 'data_id': '0x2e7a631c52d78667:0xd6899eb201af0678', 'total_reviews': 18146}
# {'Nama': 'Taman Wisata Candi Borobudur', 'data_id': '0x2e7a8ced83266877:0x2a8e6e33252aa886', 'total_reviews': 4389}
# {'Nama': 'Green Canyon / Cukang Taneuh', 'data_id': '0x2e65bfc5ed2372a9:0xf21d3ba9ffb06d10', 'total_reviews': 7509}
# {'Nama': 'Keraton Ngayogyakarta Hadiningrat', 'data_id': '0x2e7a5796db06c7ef:0x395271cf052b276c', 'total_reviews': 36415}
# {'Nama': 'Kawasan Wisata Malioboro', 'data_id': '0x2e7a578819c338f1:0x72aa3ad97ecccfb6', 'total_reviews': 5170}
# {'Nama': 'The Heritage Palace', 'data_id': '0x2e7a1598381d4625:0xe517f6b0abbdd457', 'total_reviews': 12658}
# {'Nama': 'Objek Wisata Kawasan Selo', 'data_id': '0x2e7a64f90d39453f:0xfedcac5f05048a43', 'total_reviews': 1181}
# {'Nama': 'Brown Canyon', 'data_id': '0x2e708e7e1d16e6c7:0x38cd451e8fbddbc4', 'total_reviews': 3517}
# {'Nama': 'Tebing Breksi', 'data_id': '0x2e7a5aa458b4665b:0xa4b0fc6ad0ae38c7', 'total_reviews': 64292}
# {'Nama': 'Kota Lama Semarang', 'data_id': '0x2e70f35649aa5e89:0x36af9cb064c11968', 'total_reviews': 5534}
# {'Nama': 'Candi Umbul', 'data_id': '0x2e7a80efb8cecd41:0x4b6cdcc65d34607a', 'total_reviews': 1387}

# %% [markdown]
# *   Scrapping Reviews
#
#     Mengambil 100 data dari masing-masing objek wisata sesuai dengan jumlah index yang diinginkan

# %%
data = {'nama_wisata': [],
        'nama_pereview': [],
        'rating': [],
        'review': []}

for lr in local_results:
  params = {
      "engine": "google_maps_reviews",
      "data_id": "",
      "api_key": "1e15cb862401aac1d0ceb77f9bc8a132174b60004dacfe264e7524db24e39878",
      "hl": "id",

  }

  params["data_id"] = lr["data_id"]

  search = GoogleSearch(params)

  idx = 0
  last = 30

  while idx <= last:

    results = search.get_dict()

    for Result in results["reviews"]:
      idx += 1

      if idx <= last:
        data['nama_wisata'].append(lr["Nama"]);
        data['nama_pereview'].append(Result["user"]["name"]);
        data['rating'].append(Result["rating"]);
        data['review'].append(Result["snippet"]);

    if "next" in results.get("serpapi_pagination", {}):
      search.params_dict.update(dict(parse_qsl(urlsplit(results.get("serpapi_pagination").get("next")).query)))

    else:
      break

review_original = data['review']

# %% [markdown]
# *   Export Data Scrapping to CSV

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
dfScrap = pd.DataFrame(data)
dfScrap.to_csv('/content/drive/My Drive/ReviewWisataIndonesia_GSearch.csv', index=False)
dfScrap
# Out:
# Mounted at /content/drive
#          nama_wisata       nama_pereview  rating  \
# 0    Candi Borobudur      Valian Ardhana     5.0
# 1    Candi Borobudur      Annisa Dhaniar     5.0
# 2    Candi Borobudur              Arif M     5.0
# 3    Candi Borobudur          Aldi putra     5.0
# 4    Candi Borobudur           Try Akbar     5.0
# ..               ...                 ...     ...
# 445      Candi Umbul      Ayu Wanda Sari     4.0
# 446      Candi Umbul     Daniel Rahardjo     3.0
# 447      Candi Umbul          Nenk Mulia     3.0
# 448      Candi Umbul  Buddi luhur Chanel     5.0
# 449      Candi Umbul    Danang Mardiyono     3.0
#
#                                                 review
# 0    Candi terbesar di dunia, amazing. Konon katany...
# 1    tidak diragukan lagi sebagai situs pariwisata ...
# 2    Siapa sih yang tidak kenal dengan Candi Borobu...
# 3    Amazing. Walapun ada kejadian salah pas beli t...
# 4    Keindahan pemandangan borobudur memang luar bi...
# ..                                                 ...
# 445  Senang dgn peninggalan masa lampau, walau tida...
# 446  Situs candi asli tinggal tumpukan batu\nPas sa...
# 447  Gak ada aer buat bilas.. kamar ganti nya bnr2 ...
# 448  Secara umum sudah baik namun masih dan terus d...
# 449  Pemandian air hangat. Letaknya di area sawah, ...
#
# [450 rows x 4 columns]
